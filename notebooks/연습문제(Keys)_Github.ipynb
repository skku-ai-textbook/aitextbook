# %% [markdown]
# 이 페이지는 [문과생을 위한 위한 인공지능](http://www.acornpub.co.kr/book/ai-for-student) 교재에 수록된 연습문제의 풀이 코드를 제공합니다. 본 페이지를 구글 코랩에서 여시려면 [링크](https://colab.research.google.com/drive/14jyN8ony8-7NV80MesroQrDoy4NbRLBI?usp=sharing)를 클릭하시거나 아래의 주소를 웹브라우저에 복사해 주세요.
#
# 연습문제 풀이 링크: https://colab.research.google.com/drive/14jyN8ony8-7NV80MesroQrDoy4NbRLBI?usp=sharing

# %% [markdown]
# # 연습문제 (CHAPTER 04)

# %% [markdown]
# ## [연습문제 4-1]

# %% [markdown]
# ### [연습문제 4-1-1]

# %%
30+62
# Out:
# 92

# %% [markdown]
# ### [연습문제 4-1-2]

# %%
40-21
# Out:
# 19

# %% [markdown]
# ### [연습문제 4-1-3]

# %%
15*16
# Out:
# 240

# %% [markdown]
# ### [연습문제 4-1-4]

# %%
30/5
# Out:
# 6.0

# %% [markdown]
# ### [연습문제 4-1-5]

# %%
142//10
# Out:
# 14

# %% [markdown]
# ### [연습문제 4-1-6]

# %%
50%6
# Out:
# 2

# %% [markdown]
# ## [연습문제 4-2]

# %%
int('10') + 10
# Out:
# 20

# %% [markdown]
# ## [연습문제 4-3]

# %%
str(325) + str(234)
# Out:
# '325234'

# %% [markdown]
# ## [연습문제 4-4]

# %%
money = int(input("원금은 얼마입니까?:  "))
month = int(input('몇 개월 동안 예치할 예정입니까?:  '))

money*(1+.02)**(month/12)

print('원리합계:', money*(1+.02)**(month/12))
# Out:
# 원금은 얼마입니까?:  100000
# 몇 개월 동안 예치할 예정입니까?:  36
# 원리합계: 106120.80000000002

# %% [markdown]
# ## [연습문제 4-5]

# %%
string = "문과생을 위한 인공지능 실습"
print(string[8:])
# Out:
# 인공지능 실습

# %% [markdown]
# ## [연습문제 4-6]

# %%
number = 102323923
int(str(number)[-3])
# Out:
# 9

# %% [markdown]
# ## [연습문제 4-7]

# %%
int(str(103/4)[3])
# Out:
# 7

# %% [markdown]
# # 연습문제 (CHAPTER 05)

# %% [markdown]
# ## [연습문제 5-1]

# %%
num = input("숫자로 된 문자열을 입력하세요. ")
num*int(num)
# Out:
# 숫자로 된 문자열을 입력하세요. 10
# '10101010101010101010'

# %% [markdown]
# ## [연습문제 5-2]
#
# 첫번째 수를 입력하시오: 15
# 두번째 수를 입력하시오: 32
# 더하기: 47
# 빼기: -17
# 곱하기: 480
# 나누기: 0.4687

# %%
a = int(input('첫번째 수를 입력하시오: '))
b = int(input('두번째 수를 입력하시오: '))
print('더하기: ', a+b)
print('빼기: ', a-b)
print('곱하기: ', a*b)
print('나누기: ', a/b)
# Out:
# 첫번째 수를 입력하시오: 10
# 두번째 수를 입력하시오: 20
# 더하기:  30
# 빼기:  -10
# 곱하기:  200
# 나누기:  0.5

# %% [markdown]
# 20

# %%
money=int(input("얼마를 출금하시겠습니까? "))
moeny5 = int(money // 50000)
money %= 50000
money1 = int(money // 10000)
money %= 10000
print("5만원권: {}장\n1만원권: {}장\n나머지 : {}원".format(moeny5, money1, money))
# Out:
# 얼마를 출금하시겠습니까? 1650000
# 5만원권: 33장
# 1만원권: 0장
# 나머지 : 0원

# %% [markdown]
# ## [연습문제 5-4]

# %%
words = input("암호로 사용할 문자열을 입력해주세요 :")
print("문자열 길이:", len(words))
print("암호:", words[::-1])
# Out:
# 암호로 사용할 문자열을 입력해주세요 :문과생을 위한 인공지능
# 문자열 길이: 12
# 암호: 능지공인 한위 을생과문

# %% [markdown]
# ## [연습문제 5-5]

# %%
x = 5
y = (2*(x**3)) + (5*x) + 3
print(y)
# Out:
# 278

# %% [markdown]
# ## [연습문제 5-6]

# %%
list_1 = [] # 빈리스트
list_1.append(int(input("첫번째 데이터를 입력해주세요: ")))
list_1.append(int(input("두번째 데이터를 입력해주세요: ")))
list_1.append(int(input("세번째 데이터를 입력해주세요: ")))
list_1.append(int(input("네번째 데이터를 입력해주세요: ")))
list_1.append(int(input("다섯번째 데이터를 입력해주세요: ")))
list_1.append(int(input("여섯번째 데이터를 입력해주세요: ")))
list_1.append(int(input("일곱번째 데이터를 입력해주세요: ")))

print("입력받은 값들:", list_1)
list_1.sort(reverse=True) # 큰 수부터 작은 수
print("가장 큰값은 ", list_1[0], "입니다")
print("가장 작은값은 ", list_1[-1], "입니다")

# %% [markdown]
# ## [연습문제 5-7]

# %%
dic = {'경찰서':112, '소방서':119, 'KT':100, '전화안내':114, '국정원':111, '다산콜센터':120}

x = input('전화번호를 알고 싶은 관공서의 이름을 입력해 주세요: ')
print(x+"의 전화번호는 "+str(dic[x])+"입니다.")
# Out:
# 전화번호를 알고 싶은 관공서의 이름을 입력해 주세요: 경찰서
# 경찰서의 전화번호는 112입니다

# %% [markdown]
# # 연습문제 (CHAPTER 06)

# %% [markdown]
# ## [연습문제 6-1]

# %%
year = int(input("윤년으로 판단할 연도는 언제 입니까? "))

if (year%4==0 and year%100!=0) or (year%400==0):
  print("{}년은 윤년입니다".format(year))
else:
  print("{}년은 윤년이 아닙니다".format(year))

# %% [markdown]
# ## [연습문제 6-2]

# %%
import random
answer=random.randint(1, 101)
hit = 0

while hit<8:
  guess = int(input("1에서 100사이의 숫자를 입력해보세요: "))
  hit+=1

  if hit==8:
    print("실패하셨습니다. 정답은 {}입니다".format(answer))
    break

  if guess==answer:
    print("정답입니다. 총 {}번 시도 끝에 성공하셨습니다".format(hit))
    break
  elif guess>answer:
    print("정답보다 큽니다. 총 {}번의 기회가 남았습니다".format(10-hit))
  else:
    print("정답보다 작습니다. 총 {}번의 기회가 남았습니다".format(10-hit))

# %% [markdown]
# ## [연습문제 6-3]

# %%
import random

a=random.randint(1, 101)
b=random.randint(1, 101)

answer = input("{0} + {1} = ".format(a, b))

if int(answer) == a+b:
  print("정답입니다")
else:
   print("오답입니다")
# Out:
# 32 + 9 =
# 32 + 9 = 20
# 오답입니다

# %% [markdown]
# ## [연습문제 6-4]

# %%
num = int(input("몇 단을 출력할까요? "))
print(" ")
for i in range(1, 10, 1):
  print("{} * {} = {}".format(num, i, num*i))
# Out:
# 몇 단을 출력할까요? 7
#
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63

# %% [markdown]
# ## [연습문제 6-5]

# %%
[x for x in range(1, 100, 1) if x%4==0]
# Out:
# [4,
#  8,
#  12,
#  16,
#  20,
#  24,
#  28,
#  32,
#  36,
#  40,
#  44,
#  48,
#  52,
#  56,
#  60,
#  64,
#  68,
#  72,
#  76,
#  80,
#  84,
#  88,
#  92,
#  96]

# %% [markdown]
# ## [연습문제 6-6]

# %%
dict_student = {"학생1":70, "학생2":80, "학생3":50, "학생4":75, "학생5":80,
                "학생6":100, "학생7":40, "학생8":85, "학생9":95, "학생10":60}

tresh = int(input("몇 점 이상의 학생을 출력하겠습니까? "))
dict_pass = {name:value for name,value in dict_student.items() if value>tresh}
print("{}점 이상의 학생의 총 {}명입니다.\n 학생의 리스트는 {}입니다".format(tresh, len(dict_pass), dict_pass))
# Out:
# 몇 점 이상의 학생을 출력하겠습니까? 90
# 90점 이상의 학생의 총 2명입니다.
#  학생의 리스트는 {'학생6': 100, '학생9': 95}입니다

# %% [markdown]
# # 연습문제 (CHAPTER 07)

# %% [markdown]
# ## [연습문제 7-1]

# %%
import pandas as pd

raw = pd.read_csv("https://raw.githubusercontent.com/skku-ai-textbook/aitextbook/main/data/practice4a.csv")
raw.head()
# Out:
#    rnum  rankInten rankOldAndNew      date   movieCd  salesAmt  salesShare  \
# 0     1          0           NEW  4/1/2020  20205262  48850700        19.3
# 1     2         -1           OLD  4/1/2020  20204107  31798560        12.6
# 2     3         -1           OLD  4/1/2020  20192399  30146760        11.9
# 3     4         -1           OLD  4/1/2020  20199842  19394760         7.7
# 4     5          0           NEW  4/1/2020  20206446  17246100         6.8
#
#    salesChange  audiCnt  audiAcc  scrnCnt  showCnt
# 0        100.0     6165     6165      175      509
# 1        -35.7     4105    55718      346      730
# 2        -27.4     3745   718672      341      589
# 3        -37.8     2373   545382      296      489
# 4        100.0     2148     2212      157      335

# %% [markdown]
# ## [연습문제 7-2]

# %%
raw.describe()
# Out:
#             rnum   rankInten       movieCd      salesAmt  salesShare  \
# count  300.00000  300.000000  3.000000e+02  3.000000e+02  300.000000
# mean     5.50000    1.086667  2.018544e+07  1.812403e+07    7.037000
# std      2.87708    8.747240  5.204265e+04  1.723402e+07    4.164582
# min      1.00000   -8.000000  1.988801e+07  1.159000e+06    0.800000
# 25%      3.00000    0.000000  2.019028e+07  6.974975e+06    3.800000
# 50%      5.50000    0.000000  2.020454e+07  1.277239e+07    5.950000
# 75%      8.00000    1.000000  2.020602e+07  2.203956e+07    9.725000
# max     10.00000  117.000000  2.020772e+07  1.202772e+08   20.700000
#
#         salesChange       audiCnt       audiAcc     scrnCnt     showCnt
# count    300.000000    300.000000  3.000000e+02  300.000000  300.000000
# mean     198.900333   2296.940000  1.171224e+06  195.830000  350.113333
# std     2331.667364   2126.672632  2.542927e+06  103.468062  194.154562
# ...

# %% [markdown]
# ## [연습문제 7-3]

# %%
raw['z_score'] = (raw['audiCnt']-raw['audiCnt'].mean())/raw['audiCnt'].std()

# %% [markdown]
# ## [연습문제 7-4]

# %%
print("평균: {0} | 표준편차: {1}".format(raw['z_score'].mean(), raw['z_score'].std()))
# Out:
# 평균: -4.7369515717340015e-17 | 표준편차: 1.0

# %%
raw.groupby('rankOldAndNew')[['audiCnt']].agg(['mean','std'])
# Out:
#                    audiCnt
#                       mean          std
# rankOldAndNew
# NEW            3331.440000  2838.802052
# OLD            2202.894545  2030.515443

# %% [markdown]
# ## [연습문제 7-5]

# %%
import pandas as pd

raw1 = pd.read_csv("https://raw.githubusercontent.com/skku-ai-textbook/aitextbook/main/data/practice4b.csv")
raw1.head()
# Out:
#    rnum  rankInten rankOldAndNew      date   movieCd  salesAmt  salesShare  \
# 0     1          0           OLD  5/1/2020  20205402  70128520        12.2
# 1     2          0           OLD  5/1/2020  20197397  64189060        11.2
# 2     3         11           OLD  5/1/2020  20173226  59316340        10.4
# 3     4          0           OLD  5/1/2020  20181685  54055380         9.4
# 4     5         -2           OLD  5/1/2020  20207722  48828300         8.5
#
#    salesChange  audiCnt  audiAcc  scrnCnt  showCnt
# 0        -41.7     8822    35054      281      791
# 1        -34.0     7279    26844      533      933
# 2        342.3     6391    10601      320      397
# 3        -36.1     6150    23082      444      776
# 4        -42.8     5880    28309      437      782

# %%
# append가 더 이상 사용되지 않음으로 pd.concat([df1, df2]) 형식으로 사용해야 합니다.
# 여기에서 df1 df2는 합치고자하는 데이터 프레임을 지칭합니다.
#raw2 = raw.append(raw1)

raw2 = pd.concat([raw, raw1])
raw2.shape
# Out:
# (610, 13)

# %% [markdown]
# ## [연습문제 7-6]

# %%
raw3 = pd.read_csv("https://raw.githubusercontent.com/skku-ai-textbook/aitextbook/main/data/practice4c.csv")
raw3.head()
# Out:
#    rnum  rankInten rankOldAndNew      date   movieCd  salesAmt  salesShare  \
# 0     1          0           NEW  4/1/2020  20205262  48850700        19.3
# 1     2         -1           OLD  4/1/2020  20204107  31798560        12.6
# 2     3         -1           OLD  4/1/2020  20192399  30146760        11.9
# 3     4         -1           OLD  4/1/2020  20199842  19394760         7.7
# 4     5          0           NEW  4/1/2020  20206446  17246100         6.8
#
#    salesChange
# 0        100.0
# 1        -35.7
# 2        -27.4
# 3        -37.8
# 4        100.0

# %%
raw4 = pd.read_csv("https://raw.githubusercontent.com/skku-ai-textbook/aitextbook/main/data/practice4d.csv")
raw4.head()
# Out:
#     movieCd  audiCnt  audiAcc  scrnCnt  showCnt
# 0  20205262     6165     6165      175      509
# 1  20204107     4105    55718      346      730
# 2  20192399     3745   718672      341      589
# 3  20199842     2373   545382      296      489
# 4  20206446     2148     2212      157      335

# %%
raw5 = pd.merge(raw3, raw4, how='left', on=['movieCd'])
raw5.head()
# Out:
#    rnum  rankInten rankOldAndNew      date   movieCd  salesAmt  salesShare  \
# 0     1          0           NEW  4/1/2020  20205262  48850700        19.3
# 1     1          0           NEW  4/1/2020  20205262  48850700        19.3
# 2     1          0           NEW  4/1/2020  20205262  48850700        19.3
# 3     1          0           NEW  4/1/2020  20205262  48850700        19.3
# 4     1          0           NEW  4/1/2020  20205262  48850700        19.3
#
#    salesChange  audiCnt  audiAcc  scrnCnt  showCnt
# 0        100.0     6165     6165      175      509
# 1        100.0     4799    10964      170      503
# 2        100.0     4280    15244      175      504
# 3        100.0     8288    23532      199      618
# 4        100.0     7576    31108      206      618

# %% [markdown]
# ## [연습문제 7-7]

# %%
raw.groupby('rankOldAndNew')[['salesShare','audiCnt']].agg(['mean','std'])
# Out:
#               salesShare                audiCnt
#                     mean       std         mean          std
# rankOldAndNew
# NEW             7.128000  4.329503  3331.440000  2838.802052
# OLD             7.028727  4.157345  2202.894545  2030.515443

# %% [markdown]
# # 연습문제 (CHAPTER 08)

# %% [markdown]
# ## [연습문제 8-1]

# %%
import pandas as pd

raw = pd.read_csv("https://raw.githubusercontent.com/skku-ai-textbook/aitextbook/main/data/practice5.csv")
raw.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO   B1000  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
import matplotlib.pyplot as plt
import seaborn as sns


figure, axs = plt.subplots(nrows=1, ncols=2)
figure.set_size_inches(16,8)

ax1 = sns.histplot(x='MEDV', data=raw, ax=axs[0])
ax2 = sns.histplot(x='RM', data=raw, ax=axs[1])

# %% [markdown]
# ## [연습문제 8-2]

# %%
import numpy as np
# 평균보다 높은 경우 1, 그렇지 않으면 0
raw['CRIM_ABV'] = np.where(raw['CRIM']>=raw['CRIM'].mean(),1,0)

figure, axs = plt.subplots(nrows=1, ncols=2)
figure.set_size_inches(16,8)

ax1 = sns.histplot(x='MEDV', data=raw, hue='CRIM_ABV', ax=axs[0])
ax2 = sns.histplot(x='RM', data=raw, hue='CRIM_ABV', ax=axs[1])

# %% [markdown]
# ## [연습문제 8-3]

# %%
plt.figure(figsize=(4,4))

ax = sns.boxplot(y='MEDV', x='CRIM_ABV', order=[1, 0], data=raw)
ax.set(title='RM by Crime Rate', ylabel='RM', xlabel='Crime Rates')
# Out:
# [Text(0.5, 1.0, 'RM by Crime Rate'),
#  Text(0, 0.5, 'RM'),
#  Text(0.5, 0, 'Crime Rates')]

# %% [markdown]
# ## [연습문제 8-4]

# %%
raw['AGE_ABV'] = np.where(raw['AGE']>=raw['AGE'].mean(),1,0)

plt.figure(figsize=(4,4))

ax = sns.boxplot(y='MEDV', x='CRIM_ABV', hue='AGE_ABV', order=[1, 0], data=raw)
ax.set(title='RM by Crime Rate', ylabel='RM', xlabel='Crime Rates')
# Out:
# [Text(0.5, 1.0, 'RM by Crime Rate'),
#  Text(0, 0.5, 'RM'),
#  Text(0.5, 0, 'Crime Rates')]

# %% [markdown]
# ## [연습문제 8-5]

# %%
plt.figure(figsize=(4,4))

ax = sns.scatterplot(x='RM', y='MEDV', hue='AGE_ABV', data=raw)

# %% [markdown]
# ## [연습문제 8-6]

# %%
plt.figure(figsize=(4,4))

ax = sns.scatterplot(x='RM', y='MEDV', size='AGE_ABV', data=raw)

# %% [markdown]
# ## [연습문제 8-7]

# %%
flight = sns.load_dataset("flights")
flight.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flight_pivot = flight.pivot('year','month','passengers')
flight_pivot
# Out:
# <ipython-input-49-42ac27a5ccee>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flight_pivot = flight.pivot('year','month','passengers')
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# ...

# %% [markdown]
# ## [연습문제 8-8]

# %%
plt.figure(figsize=(5,5))

ax = sns.heatmap(flight_pivot)

# %% [markdown]
# ## [연습문제 8-9, 8-10]
#
# 연습문제 8-9, 8-10은 언론진흥재단의 빅카인즈 서비스를 사용해 직접 워드클라우드를 시각화하는 문제이기 때문에 연습문제의 예제가 제공되지 않습니다. 두 연습문제는 직접 데이터를 구해서 코드 예제 8-28부터 코드 예제 8-40을 참조하여 연습문제를 해결하면 됩니다.

# %% [markdown]
# # 연습문제 (CHAPTER 13)

# %% [markdown]
# ## [연습문제 13-1]

# %%
import pandas as pd

raw = pd.read_csv("https://raw.githubusercontent.com/skku-ai-textbook/aitextbook/main/data/practice6.csv")

raw.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO   B1000  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# ## [연습문제 13-2]

# %%
import sklearn
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
X = raw.drop(columns=['MEDV'])
Y = raw[['MEDV']]
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=.25, random_state=0)

# %%
features = ['CRIM', 'RM', 'AGE']

regr = linear_model.LinearRegression()
regr.fit(X_train[features], y_train['MEDV'])
# Out:
# LinearRegression()

# %% [markdown]
# ## [연습문제 13-3]

# %%
print('모델의 절편: {int:8.3f}'.format(int=regr.intercept_))

for i, labels in enumerate(features):
    print('특성 ({lab:11})의 회귀 계수 값은 : {coef:8.3f}'.format(lab=labels, coef=regr.coef_[i]))
# Out:
# 모델의 절편:  -23.799
# 특성 (CRIM       )의 회귀 계수 값은 :   -0.257
# 특성 (RM         )의 회귀 계수 값은 :    8.141
# 특성 (AGE        )의 회귀 계수 값은 :   -0.060

# %%
import matplotlib.pyplot as plt
import seaborn as sns

figure.set_size_inches(5, 5)
sns.barplot(x=regr.coef_, y=features)
# Out:
# <Axes: >

# %% [markdown]
# ## [연습문제 13-4]

# %%
reg_pred = regr.predict(X_test[features])
reg_r2 = sklearn.metrics.r2_score(y_test, reg_pred)
reg_rmse = np.sqrt(sklearn.metrics.mean_squared_error(y_test, reg_pred))

print('\nR2: {0:.3f} %'.format(reg_r2*100))
print('\nRMSE: {0:.3f}'.format(reg_rmse))
# Out:
# R2: 45.142 %
#
# RMSE: 6.695

# %% [markdown]
# ## [연습문제 13-5]

# %%
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train['MEDV'])
# Out:
# LinearRegression()

# %%
reg_pred = regr.predict(X_test)
reg_r2 = sklearn.metrics.r2_score(y_test, reg_pred)
reg_rmse = np.sqrt(sklearn.metrics.mean_squared_error(y_test, reg_pred))

print('\nR2: {0:.3f} %'.format(reg_r2*100))
print('\nRMSE: {0:.3f}'.format(reg_rmse))
# Out:
# R2: 63.546 %
#
# RMSE: 5.457

# %% [markdown]
# ## [연습문제 13-6]

# %%
lm = linear_model.LinearRegression()

folds = KFold(n_splits = 5, shuffle = True, random_state = 1)

r2_scores = cross_val_score(lm, X, Y, scoring='r2', cv=folds)

nrmse_scores = cross_val_score(lm, X, Y, scoring='neg_root_mean_squared_error', cv=folds)

print("K-fold R^2 값 들: "+str(r2_scores))
print("K-fold R^2 평균값: {0:.3f}% ".format(100*r2_scores.mean()))

print("\nK-fold RMSE 값 들: "+str(nrmse_scores*-1))
print("K-fold RMSE 스코어: {0:.3f} ".format(nrmse_scores.mean()*-1))
# Out:
# K-fold R^2 값 들: [0.76341744 0.64681426 0.79214772 0.65075105 0.73525883]
# K-fold R^2 평균값: 71.768%
#
# K-fold RMSE 값 들: [4.83537346 5.34923472 3.89366236 5.21614992 4.83437406]
# K-fold RMSE 스코어: 4.826

# %% [markdown]
# # 연습문제 (CHAPTER 14)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import average_precision_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_auc_score

# %% [markdown]
# ROC커브를 시각화하기 위해 사용했던 명령어(`plot_roc_curve `)는 최신 `sklearn` 버전부터 `RoCCurveDisplay.from_estimator`로 변경하여 사용해야 합니다.

# %%
from sklearn.metrics import RocCurveDisplay

# %%
import pandas as pd

raw = pd.read_csv("https://raw.githubusercontent.com/skku-ai-textbook/aitextbook/main/data/practice7.csv")
raw.head()
# Out:
#    age  sex  income  education  live_in_city  own_smartphone  own_tablet  \
# 0   52    0      11          5             1               1           0
# 1   47    1       1          5             1               1           0
# 2   54    0      11          5             1               1           0
# 3   48    0       9          5             1               1           0
# 4   45    1       1          4             1               1           0
#
#    sns_use  newspaper
# 0        1          1
# 1        1          1
# 2        1          1
# 3        0          1
# 4        0          0

# %% [markdown]
# ## [연습문제 14-1]

# %%
X = raw.drop(columns=['sns_use'])
Y = raw[['sns_use']]

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=1)

# %% [markdown]
# ## [연습문제 14-2]

# %%
list_of_features = ['sex','income']

svm = SVC(probability=True)

svm.fit(X_train[list_of_features], y_train['sns_use'])

preds = svm.predict(X_test[list_of_features])
cf_matrix = confusion_matrix(y_test['sns_use'], preds)

# %%
print(cf_matrix)
# Out:
# [[508 181]
#  [334 227]]

# %% [markdown]
# ## [연습문제 14-3]

# %%
tn, fp, fn, tp = (cf_matrix[0,0], cf_matrix[0, 1],
                  cf_matrix[1,0], cf_matrix[1,1])

# %%
accuracy = (tp+tn)/(tp+fp+tn+fn)
precision = (tp)/(tp+fp)
recall  = (tp)/(tp+fn)
f1 = 2*(precision*recall)/(precision+recall)

print("모델 정확도     : {0:.3f}".format(accuracy))
print("모델 정밀도     : {0:.3f}".format(precision))
print("모델 재현도     : {0:.3f}".format(recall))
print("모델 F-1 스코어 : {0:.3f}".format(f1))
# Out:
# 모델 정확도     : 0.588
# 모델 정밀도     : 0.556
# 모델 재현도     : 0.405
# 모델 F-1 스코어 : 0.469

# %%
accuracy_svm1 = accuracy_score(y_test, preds)
precision_svm1 = precision_score(y_test, preds)
recall_svm1 = recall_score(y_test, preds)
f1_svm1 = f1_score(y_test, preds)

print("모델 정확도    : {s:8.3f}".format(s=accuracy_svm1))
print("모델 정밀도    : {s:8.3f}".format(s=precision_svm1))
print("모델 재현도    : {s:8.3f}".format(s=recall_svm1))
print("모델 F-1스코어 : {s:8.3f}".format(s=f1_svm1))
# Out:
# 모델 정확도    :    0.588
# 모델 정밀도    :    0.556
# 모델 재현도    :    0.405
# 모델 F-1스코어 :    0.469

# %% [markdown]
# ## [연습문제 14-4]

# %%
# 아래의 코드를 수정하여 문제를 풀어주세요

for i in [.1, 1, 30, 50, 100]:
  svm = SVC(C=i, probability=True, random_state=0)

  svm.fit(X_train[list_of_features], y_train['sns_use'])

  preds = svm.predict(X_test[list_of_features])

  acc = accuracy_score(y_test, preds)
  pre = precision_score(y_test, preds)
  rec = recall_score(y_test, preds)
  f1 = f1_score(y_test, preds)


  print("\n비용이 {:5}인 모델의 정확도: {:5.3f} | 정밀도: {:5.3f} | 재현도: {:5.3f} | F1스코어: {:5.3f}".format(i, acc, pre, rec, f1))
# Out:
# 비용이   0.1인 모델의 정확도: 0.557 | 정밀도: 0.518 | 재현도: 0.178 | F1스코어: 0.265
#
# 비용이     1인 모델의 정확도: 0.588 | 정밀도: 0.556 | 재현도: 0.405 | F1스코어: 0.469
#
# 비용이    30인 모델의 정확도: 0.588 | 정밀도: 0.556 | 재현도: 0.405 | F1스코어: 0.469
#
# 비용이    50인 모델의 정확도: 0.588 | 정밀도: 0.556 | 재현도: 0.405 | F1스코어: 0.469
#
# 비용이   100인 모델의 정확도: 0.588 | 정밀도: 0.556 | 재현도: 0.405 | F1스코어: 0.469

# %% [markdown]
# ## [연습문제 14-5]

# %%
svm = SVC(C=1, probability=True, random_state=0)
svm.fit(X_train[list_of_features], y_train['sns_use'])

roc_plot = RocCurveDisplay.from_estimator(svm,
                                          X_test[list_of_features], y_test, name="Scikit-Learn ROC Curve")

# %% [markdown]
# ## [연습문제 14-6]

# %%
svm = SVC(C=1, probability=True, random_state=0)
svm.fit(X_train, y_train['sns_use'])


roc_plot = RocCurveDisplay.from_estimator(svm,
                                          X_test, y_test, name="Scikit-Learn ROC Curve")

# %% [markdown]
# ## [연습문제 14-7]

# %%
folds = KFold(n_splits = 5, shuffle = True, random_state = 83731)

svc = SVC(probability=True)

accuracy_SVM = cross_val_score(svc, X, Y['sns_use'], scoring='accuracy', cv=folds)
precision_SVM = cross_val_score(svc, X, Y['sns_use'], scoring='precision', cv=folds)
recall_SVM = cross_val_score(svc, X, Y['sns_use'], scoring='recall', cv=folds)
f1_SVM = cross_val_score(svc, X, Y['sns_use'], scoring='f1', cv=folds)
roc_auc_SVM = cross_val_score(svc, X, Y['sns_use'], scoring='roc_auc', cv=folds)

print("\n정확도 평균: {s:8.3f}".format(s=accuracy_SVM.mean()))
print("정밀도 평균: {s:8.3f}".format(s=precision_SVM.mean()))
print("재현도 평균: {s:8.3f}".format(s=recall_SVM.mean()))
print("F-1스코어 평균: {s:8.3f}".format(s=f1_SVM.mean()))
print("AUC커브 평균: {s:8.3f}".format(s=roc_auc_SVM.mean()))
# Out:
# 정확도 평균:    0.715
# 정밀도 평균:    0.693
# 재현도 평균:    0.657
# F-1스코어 평균:    0.674
# AUC커브 평균:    0.800

# %% [markdown]
# # 연습문제 (CHAPTER 15)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
import pandas as pd

raw = pd.read_csv("https://raw.githubusercontent.com/skku-ai-textbook/aitextbook/main/data/practice8.csv")
raw.head()
# Out:
#    MEDV     DIS   AGE     RM
# 0  24.0  4.0900  65.2  6.575
# 1  21.6  4.9671  78.9  6.421
# 2  34.7  4.9671  61.1  7.185
# 3  33.4  6.0622  45.8  6.998
# 4  36.2  6.0622  54.2  7.147

# %% [markdown]
# ## [연습문제 15-1]

# %%
# 모델 선언
kmeans = KMeans(n_clusters = 4, random_state=830731)
# 모델 학습
kmeans.fit(raw[['AGE', 'RM']])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4, random_state=830731)

# %% [markdown]
# ## [연습문제 15-2]

# %%
kmeans.labels_

raw['cluster'] = kmeans.labels_
print(raw['cluster'].value_counts())
# Out:
# 1    237
# 0    103
# 2    101
# 3     65
# Name: cluster, dtype: int64

# %% [markdown]
# ## [연습문제 15-3]

# %%
centers = kmeans.cluster_centers_
print(centers)

print("\n그룹 별 RM 비교\n")
print(raw.groupby('cluster')['RM'].describe().applymap("{0:.3f}".format))
print("\n그룹 별 AGE 비교\n")
print(raw.groupby('cluster')['AGE'].describe().applymap("{0:.3f}".format))
# Out:
# [[68.91456311  6.37552427]
#  [93.39029536  6.11516456]
#  [41.96831683  6.4460396 ]
#  [18.89846154  6.50772308]]
#
# 그룹 별 RM 비교
#
#            count   mean    std    min    25%    50%    75%    max
# cluster
# 0        103.000  6.376  0.654  5.390  5.891  6.193  6.663  8.337
# 1        237.000  6.115  0.758  3.561  5.713  6.112  6.434  8.780
# 2        101.000  6.446  0.605  4.973  6.014  6.316  6.782  8.034
# 3         65.000  6.508  0.558  5.412  6.127  6.481  6.861  8.259
#
# 그룹 별 AGE 비교
#
#            count    mean    std     min     25%     50%     75%      max
# cluster
# 0        103.000  68.915  7.387  56.000  62.350  69.600  74.950   80.800
# 1        237.000  93.390  5.591  81.300  89.100  94.600  98.200  100.000
# 2        101.000  41.968  7.555  30.800  34.900  41.500  48.200   54.400
# 3         65.000  18.898  7.532   2.900  14.700  19.100  24.800   30.200

# %% [markdown]
# ## [연습문제 15-4]
#
# Python의 변화로 군집 중심점에 군집의 번호를 표기하기 위한 아규먼트가 `marker=f'${i}$'`로 변경되었습니다.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns

# %%
figure, (ax1) = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(6,6)


sns.scatterplot(x=raw['AGE'], y=raw['RM'], hue=raw['cluster'], ax=ax1)

ax1.yaxis.set_major_locator(mpl.ticker.MultipleLocator(10))


ax1.scatter(centers[:, 0], centers[:, 1], marker='s',
            c="white", alpha=1, s=300, edgecolor='black')

for i, c in enumerate(centers):
    ax1.scatter(c[0], c[1], marker=f'${i}$', alpha=1,
                color='black')

# %% [markdown]
# ## [연습문제 15-5]

# %%
raw['sil_coef'] = silhouette_samples(raw[['RM','AGE']], raw['cluster'])

print(raw.groupby('cluster')['sil_coef'].describe().applymap("{0:.3f}".format))
# Out:
#            count   mean    std    min    25%    50%    75%    max
# cluster
# 0        103.000  0.514  0.203  0.046  0.368  0.580  0.692  0.743
# 1        237.000  0.700  0.182  0.019  0.686  0.781  0.806  0.819
# 2        101.000  0.477  0.203  0.051  0.304  0.547  0.667  0.723
# 3         65.000  0.581  0.198  0.026  0.536  0.669  0.723  0.736

# %%
average_score = silhouette_score(raw[['RM','AGE']], raw['cluster'])
print('silhouette_score를 사용해 구한 실루엣 분석 점수:{0:15.3f}'.format(average_score))
# Out:
# silhouette_score를 사용해 구한 실루엣 분석 점수:          0.603

# %% [markdown]
# ## [연습문제 15-6]

# %%
for i in range(2,11):

    kmeans = KMeans(n_clusters = i, random_state=1)

    raw[str('cluster_'+str(i))]  = kmeans.fit_predict(raw[['RM','AGE']])

    raw[str('coef_'+str(i))] = silhouette_samples(raw[['RM','AGE']], raw[str('cluster_'+str(i))])

    average_score = silhouette_score(raw[['RM','AGE']], raw[str('cluster_'+str(i))] )

    print("데이터를 {k:2} 개의 집단으로 나누는 k-평균 군집 분석의 실루엣 계수 평균: {mean:5.3f}".format(k=i, mean=average_score))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 데이터를  2 개의 집단으로 나누는 k-평균 군집 분석의 실루엣 계수 평균: 0.692
# 데이터를  3 개의 집단으로 나누는 k-평균 군집 분석의 실루엣 계수 평균: 0.640
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# ## [연습문제 15-7]

# %%
for k in [2, 3, 4]:

    sil_plot = raw[['cluster_'+str(k), 'coef_'+str(k)]]
    sil_plot.columns = ['cluster', 'coef']

    sil_plot = sil_plot.sort_values(by=['cluster','coef'],
        ascending=[True, False]).reset_index()

    sil_plot['id'] = pd.Series(range(0,len(sil_plot)))

    sil_plot['under_avg'] = np.where(sil_plot['coef']>sil_plot['coef'].
        mean() , 0, 1)


    kmeans = KMeans(n_clusters = k, random_state=830731)
    kmeans.fit(raw[['AGE', 'RM']])

    centers= kmeans.cluster_centers_

    figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
    figure.set_size_inches(18,6)


    sns.lineplot(
       data=sil_plot, x="id", y='coef', hue="cluster",
            style='under_avg', ax=ax1)

    ax1.axhline(y=sil_plot['coef'].mean(), color="black", linestyle="--")
    ax1.axhline(y=0, color="black", linestyle="-")

    ax1.set_xticks(sil_plot.groupby('cluster')['id'].median())
    ax1.set(xticklabels=sil_plot['cluster'].unique())

    ax1.set_title("K-Means Clustering Average Coefficient:{0:.3f}".format(sil_plot['coef'].mean()))
    ax1.set_xlabel("cluster")
    ax1.set_ylabel("Coefficient")

    sns.scatterplot(x=raw['AGE'], y=raw['RM'], hue=raw['cluster_'+str(k)],
        ax=ax2)

    ax2.yaxis.set_major_locator(mpl.ticker.MultipleLocator(5))

    ax2.scatter(centers[:, 0], centers[:, 1], marker='s',
                c="white", alpha=1, s=300, edgecolor='black')

    # 변경된 코드
    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker=f'${i}$', alpha=1,
                    color='black')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# # 연습문제 (CHAPTER 16)

# %% [markdown]
# ## [연습문제 16-1~5]
#
# 챕터 16의 연습문제 1-5의 경우 독자 여러분 스스로 데이터를 구해 토픽 모델링을 수행해보는 문제입니다. 따라서 연습문제의 해답이 주어지지 않습니다.
